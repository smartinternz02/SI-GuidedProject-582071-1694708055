# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[32,53,16,15,'medium'],
                   [35,13,26,8,'medium'],
                   [57,43,17,9,'high'],
                   [43,16,19,4,'low'],
                   [59,61,28,17,'high'],
                   [49,4,8,14,'very-low'],
                   [13,24,18,32,'very-low'],
                   [np.nan,58,14,43,'medium']])

# %%
df.columns = ['mathscore','sciencescore','vocabulary','computer','performance']

# %%
df
# Out:
#    mathscore  sciencescore  vocabulary  computer performance
# 0       32.0            53          16        15      medium
# 1       35.0            13          26         8      medium
# 2       57.0            43          17         9        high
# 3       43.0            16          19         4         low
# 4       59.0            61          28        17        high
# 5       49.0             4           8        14    very-low
# 6       13.0            24          18        32    very-low
# 7        NaN            58          14        43      medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mathscore     7 non-null      float64
#  1   sciencescore  8 non-null      int64
#  2   vocabulary    8 non-null      int64
#  3   computer      8 non-null      int64
#  4   performance   8 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 448.0+ bytes

# %%
df.describe()
# Out:
#        mathscore  sciencescore  vocabulary   computer
# count   7.000000       8.00000    8.000000   8.000000
# mean   41.142857      34.00000   18.250000  17.750000
# std    16.066825      22.39898    6.386369  13.220655
# min    13.000000       4.00000    8.000000   4.000000
# 25%    33.500000      15.25000   15.500000   8.750000
# 50%    43.000000      33.50000   17.500000  14.500000
# 75%    53.000000      54.25000   20.750000  20.750000
# max    59.000000      61.00000   28.000000  43.000000

# %%
df.loc[4]
# Out:
# mathscore       59.0
# sciencescore      61
# vocabulary        28
# computer          17
# performance     high
# Name: 4, dtype: object

# %%
df.isnull().sum()
# Out:
# mathscore       1
# sciencescore    0
# vocabulary      0
# computer        0
# performance     0
# dtype: int64

# %%
df.mathscore.median()
# Out:
# 43.0

# %%
df.mathscore=df.mathscore.fillna(df.mathscore.median())

# %%
df
# Out:
#    mathscore  sciencescore  vocabulary  computer performance
# 0       32.0            53          16        15      medium
# 1       35.0            13          26         8      medium
# 2       57.0            43          17         9        high
# 3       43.0            16          19         4         low
# 4       59.0            61          28        17        high
# 5       49.0             4           8        14    very-low
# 6       13.0            24          18        32    very-low
# 7       43.0            58          14        43      medium
